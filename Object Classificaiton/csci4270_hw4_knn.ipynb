# %%
# REDACTED CODE (IMPORTS AND GETTING MNIST DATASET)

# %%
# REDACTE CODE (PRINT DATA FROM MNIST)
# Out:
# Number of training images: 60000
# Number of testing images: 10000

# %%
# REDACTED CODE (NORMALIZING DATA INTO FEATURE VECTORS)

# %%
# REDACTED CODE (OUTPUT STATISTIC FUNCTIONS)

# %%
# REDACTED CODE (TESTING ABOVE FUNCTIONS ON SAMPLE I/O DATA, NOT ACTUAL CLASSIFIER)
# Out:
# accuracy: 0.55
#
# Per class accuracy
# 0: 0.50
# 1: 0.60
# 2: 0.67
# 3: 0.50
# 4: 0.50
#
# Confusion matrix
#  0:  3  1  2  0  0
#  1:  0  3  0  0  2
#  2:  0  0  2  1  0
#  3:  0  1  0  1  0
#  4:  1  0  1  0  2

# %%
# REDACTED CODE (DATA FORMATTING FOR ABOVE FUNCTIONS)

# %%
# REDACTED CODE (KNN DEFINITION AND ACCURACY AFTER TRAINING)
# Out:
# 0.869

# %%
# REDACTED CODE (VARYING k=8)
# Out:
# 0.861

# %%
# REDACTED CODE (VARYING k=6)
# Out:
# 0.867

# %%
# REDACTED CODE (VARYING k=4)
# Out:
# 0.867

# %%
# REDACTED CODE (VARYING k=2)
# Out:
# 0.881

# %%
# REDACTED CODE (VARYING WEIGHT DISTRIBUTION)
# Out:
# 0.868

# %%
# REDACTED CODE (TESTING KNN ON BEST K AND WEIGHT DISTRIBUTION)
# Out:
# accuracy: 0.86
#
# Per class accuracy
# 0: 0.72
# 1: 0.98
# 2: 0.69
# 3: 0.90
# 4: 0.76
# 5: 0.99
# 6: 0.79
# 7: 0.89
# 8: 0.98
# 9: 0.91
#
# Confusion matrix
#  0: 905  6 29 61  7  0 233  0 14  1
#  1:  3 981  2 13  1  0  3  0  1  0
#  2: 25  0 844 19 169  0 161  0 11  0
#  3: 11  8  7 860 40  0 24  0  3  0
#  4:  4  2 85 30 761  0 108  0  5  0
#  5:  1  0  0  0  0 884  0  6  0  2
#  6: 44  2 33 15 19  0 464  0  8  0
#  7:  1  0  0  0  0 56  0 968  5 53
#  8:  6  1  0  2  3  0  7  0 951  0
#  9:  0  0  0  0  0 60  0 26  2 944

# %% [markdown]
# ## Discussion
# For reference, the classes are, in order, ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'] <br>
# We can see from the class accuracies that the algorithm performed the best with Trouser, Sandal, and Bag. The algorithm performed worse with Pullover, T-Shirt, Coat, and Shirt. These performances make sense because Trousers are very uniquely shaped in comparison to the other classifications, the same is true for Bags. The sandals tend to be very spacious as well.
# <br><br>
# For the classes that the algorithm did worse, we see the following from the confusion matrix:
# <br><br>
# **T-Shirt** were most commonly mistaken as **Shirt**<br>
# **Pullover** were most commonly mistaken as **Coat** and **Shirt**<br>
# **Coat** were most commonly mistaken as **Shirt**<br>
# **Shirt** were most commonly mistaken as **T-Shirt/top** but mistakes vary.<br><br>
# I was surprised about the good accuracy obtained from a KNN classifier but then again this is a simpler MNIST classifier than Part 2 of this homework. As for the most important statistics, the varying I did didn't show too much variation and running the tests several times saw variation in the data (i.e. the "best" k value changed from 6 to 2). From what I tested it seems the k-value is the most important.
